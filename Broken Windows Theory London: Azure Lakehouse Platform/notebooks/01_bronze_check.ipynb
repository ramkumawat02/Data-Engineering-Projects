# %%
# %run ./00_config

# %%
print(" Bronze Files Checking here ...")

display(dbutils.fs.ls(Bronze_Base))
display(dbutils.fs.ls(f"{Bronze_Base}/mps_crime"))
display(dbutils.fs.ls(f"{Bronze_Base}/fly_tipping"))
display(dbutils.fs.ls(f"{Bronze_Base}/community_strength"))

print("Bronze Files checking completed")
