# %%
print("Databricks Serverless Working")

# %%
storage_account = "retailsprojectstorage"

print(f"Storage Account: {storage_account}")

# %%
dbutils.fs.ls("/")

# %%
spark.sql("SHOW CATALOGS").show(truncate=False)

# %%
spark.sql("SHOW SCHEMAS IN retail_project_dbricks").show(truncate=False)

# %%
spark.sql("USE CATALOG retail_project_dbricks")
spark.sql("SHOW SCHEMAS").show(truncate=False)

# %%
spark.sql("""
CREATE TABLE retail_project_dbricks.default.test_table (
    id INT,
    name STRING
)
USING DELTA
""")

# %%
spark.sql("""
SHOW TABLES IN retail_project_dbricks.default
""").show(truncate=False)

# %%
spark.sql("""
CREATE VOLUME retail_project_dbricks.default.retail_volume
""")

# %%
spark.sql("""
SHOW VOLUMES IN retail_project_dbricks.default
""").show(truncate=False)

# %%
display(dbutils.fs.ls("/Volumes/retail_project_dbricks/default/retail_volume"))
