# %%
# data quality checks 
bronze_count = spark.table(
    "retail_project_dbricks.default.bronze_retail_raw"
).count()

silver_count = spark.table(
    "retail_project_dbricks.default.silver_retail_clean"
).count()

print(f"Bronze Rows: {bronze_count}")
print(f"Silver Rows: {silver_count}")

assert silver_count < bronze_count

# %%
# %sql
SELECT *
FROM retail_project_dbricks.default.gold_top_products
ORDER BY TotalRevenue DESC
LIMIT 10

# %%
# %sql
SELECT
Country,
SUM(TotalRevenue) Revenue
FROM retail_project_dbricks.default.gold_monthly_revenue
GROUP BY Country
ORDER BY Revenue DESC

# %%
# %sql
SELECT *
FROM retail_project_dbricks.default.gold_monthly_revenue
ORDER BY Year, Month
